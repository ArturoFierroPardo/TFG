# %%
ruta_txt = 'textoplano.txt'
with open(ruta_txt, 'r', encoding='utf-8') as f:
    raw = f.read()
print(raw[:500])
# Out:
# El concepto de un cuerpo tan denso que ni siquiera la luz puede escapar de él fue descrito en un artículo enviado en 1783 a la Royal Society por el geólogo y clérigo inglés John Michell. Por aquel entonces la teoría de Newton de la gravitación y el concepto de velocidad de escape eran muy conocidas. Michell calculó que un cuerpo con una densidad 500 veces mayor que la del Sol, pero con su mismo radio, tendría, en su superficie, una velocidad de escape igual a la de la luz y sería invisible. En 1

# %%
import spacy
nlp = spacy.load("es_core_news_sm")
doc = nlp(raw)
sentences = list(doc.sents)
for sent in sentences[:2]:
    print(sent)
# Out:
# El concepto de un cuerpo tan denso que ni siquiera la luz puede escapar de él fue descrito en un artículo enviado en 1783 a la Royal Society por el geólogo y clérigo inglés John Michell.
# Por aquel entonces la teoría de Newton de la gravitación y el concepto de velocidad de escape eran muy conocidas.

# %%
import nltk
from nltk.tokenize import TweetTokenizer
tokenizer = TweetTokenizer()
tokens = tokenizer.tokenize(raw)
print(tokens[:10])

for token in nlp(doc):
    print(token.text, '=>', token.pos_, '=>', token.tag_)
# Out:
# ['El', 'concepto', 'de', 'un', 'cuerpo', 'tan', 'denso', 'que', 'ni', 'siquiera']
# El => DET => DET
# concepto => NOUN => NOUN
# de => ADP => ADP
# un => DET => DET
# cuerpo => NOUN => NOUN
# tan => ADV => ADV
# denso => ADJ => ADJ
# que => SCONJ => SCONJ
# ni => CCONJ => CCONJ
# siquiera => NOUN => NOUN
# la => DET => DET
# luz => NOUN => NOUN
# puede => AUX => AUX
# escapar => VERB => VERB
# de => ADP => ADP
# él => PRON => PRON
# fue => AUX => AUX
# descrito => VERB => VERB
# en => ADP => ADP
# un => DET => DET
# artículo => NOUN => NOUN
# enviado => ADJ => ADJ
# en => ADP => ADP
# 1783 => NOUN => NOUN
# a => ADP => ADP
# la => DET => DET
# Royal => PROPN => PROPN
# Society => PROPN => PROPN
# por => ADP => ADP
# el => DET => DET
# geólogo => NOUN => NOUN
# y => CCONJ => CCONJ
# clérigo => NOUN => NOUN
# inglés => ADJ => ADJ
# John => PROPN => PROPN
# Michell => PROPN => PROPN
# . => PUNCT => PUNCT
# Por => ADP => ADP
# aquel => PRON => PRON
# entonces => ADV => ADV
# la => DET => DET
# teoría => NOUN => NOUN
# de => ADP => ADP
# Newton => PROPN => PROPN
# de => ADP => ADP
# la => DET => DET
# gravitación => NOUN => NOUN
# y => CCONJ => CCONJ
# el => DET => DET
# concepto => NOUN => NOUN
# de => ADP => ADP
# velocidad => NOUN => NOUN
# de => ADP => ADP
# escape => NOUN => NOUN
# eran => AUX => AUX
# muy => ADV => ADV
# conocidas => ADJ => ADJ
# . => PUNCT => PUNCT
# Michell => PROPN => PROPN
# calculó => VERB => VERB
# que => SCONJ => SCONJ
# un => DET => DET
# cuerpo => NOUN => NOUN
# con => ADP => ADP
# una => DET => DET
# densidad => NOUN => NOUN
# 500 => NUM => NUM
# veces => NOUN => NOUN
# mayor => ADJ => ADJ
# que => SCONJ => SCONJ
# la => DET => DET
# del => ADP => ADP
# Sol => PROPN => PROPN
# , => PUNCT => PUNCT
# pero => CCONJ => CCONJ
# con => ADP => ADP
# su => DET => DET
# mismo => DET => DET
# radio => NOUN => NOUN
# , => PUNCT => PUNCT
# tendría => VERB => VERB
# , => PUNCT => PUNCT
# en => ADP => ADP
# su => DET => DET
# superficie => NOUN => NOUN
# , => PUNCT => PUNCT
# una => DET => DET
# velocidad => NOUN => NOUN
# de => ADP => ADP
# escape => NOUN => NOUN
# igual => ADJ => ADJ
# a => ADP => ADP
# la => DET => DET
# de => ADP => ADP
# la => DET => DET
# luz => NOUN => NOUN
# y => CCONJ => CCONJ
# sería => AUX => AUX
# invisible => ADJ => ADJ
# . => PUNCT => PUNCT
# En => ADP => ADP
# 1796 => NOUN => NOUN
# el => DET => DET
# matemático => NOUN => NOUN
# francés => ADJ => ADJ
# Pierre-Simon => PROPN => PROPN
# Laplace => PROPN => PROPN
# explicó => VERB => VERB
# en => ADP => ADP
# las => DET => DET
# dos => NUM => NUM
# primeras => ADJ => ADJ
# ediciones => NOUN => NOUN
# de => ADP => ADP
# su => DET => DET
# libro => NOUN => NOUN
# Exposition => PROPN => PROPN
# du => PROPN => PROPN
# Systeme => PROPN => PROPN
# du => PROPN => PROPN
# Monde => PROPN => PROPN
# la => DET => DET
# misma => DET => DET
# idea => NOUN => NOUN
# , => PUNCT => PUNCT
# aunque => SCONJ => SCONJ
# , => PUNCT => PUNCT
# al => ADP => ADP
# ganar => VERB => VERB
# terreno => NOUN => NOUN
# la => DET => DET
# idea => NOUN => NOUN
# de => ADP => ADP
# que => SCONJ => SCONJ
# la => DET => DET
# luz => NOUN => NOUN
# era => AUX => AUX
# una => DET => DET
# onda => NOUN => NOUN
# sin => ADP => ADP
# masa => NOUN => NOUN
# , => PUNCT => PUNCT
# en => ADP => ADP
# el => DET => DET
# siglo => NOUN => NOUN
# XIX => NOUN => NOUN
# fue => AUX => AUX
# descartada => VERB => VERB
# en => ADP => ADP
# ediciones => NOUN => NOUN
# posteriores => ADJ => ADJ
# . => PUNCT => PUNCT
#
#
#  => SPACE => SPACE
# En => ADP => ADP
# 1915 => NOUN => NOUN
# Einstein => PROPN => PROPN
# desarrolló => VERB => VERB
# la => DET => DET
# relatividad => NOUN => NOUN
# general => ADJ => ADJ
# y => CCONJ => CCONJ
# demostró => VERB => VERB
# que => SCONJ => SCONJ
# la => DET => DET
# luz => NOUN => NOUN
# era => AUX => AUX
# influida => VERB => VERB
# por => ADP => ADP
# la => DET => DET
# interacción => NOUN => NOUN
# gravitatoria => ADJ => ADJ
# . => PUNCT => PUNCT
# Unos => DET => DET
# meses => NOUN => NOUN
# después => ADV => ADV
# Karl => PROPN => PROPN
# Schwarzschild => PROPN => PROPN
# encontró => VERB => VERB
# una => DET => DET
# solución => NOUN => NOUN
# a => ADP => ADP
# las => DET => DET
# ecuaciones => NOUN => NOUN
# de => ADP => ADP
# Einstein => PROPN => PROPN
# , => PUNCT => PUNCT
# donde => PRON => PRON
# un => DET => DET
# cuerpo => NOUN => NOUN
# pesado => ADJ => ADJ
# absorbería => VERB => VERB
# la => DET => DET
# luz => NOUN => NOUN
# . => PUNCT => PUNCT
# Se => PRON => PRON
# sabe => VERB => VERB
# ahora => ADV => ADV
# que => SCONJ => SCONJ
# el => DET => DET
# radio => NOUN => NOUN
# de => ADP => ADP
# Schwarzschild => PROPN => PROPN
# es => AUX => AUX
# el => DET => DET
# radio => NOUN => NOUN
# del => ADP => ADP
# horizonte => NOUN => NOUN
# de => ADP => ADP
# sucesos => NOUN => NOUN
# de => ADP => ADP
# un => DET => DET
# agujero => NOUN => NOUN
# negro => ADJ => ADJ
# que => SCONJ => SCONJ
# no => ADV => ADV
# gira => VERB => VERB
# , => PUNCT => PUNCT
# pero => CCONJ => CCONJ
# esto => PRON => PRON
# no => ADV => ADV
# era => AUX => AUX
# bien => ADV => ADV
# entendido => ADJ => ADJ
# en => ADP => ADP
# aquel => PRON => PRON
# entonces => ADV => ADV
# . => PUNCT => PUNCT
# El => DET => DET
# propio => ADJ => ADJ
# Schwarzschild => PROPN => PROPN
# pensó => VERB => VERB
# que => SCONJ => SCONJ
# no => ADV => ADV
# era => AUX => AUX
# más => ADV => ADV
# que => SCONJ => SCONJ
# una => DET => DET
# solución => NOUN => NOUN
# matemática => ADJ => ADJ
# , => PUNCT => PUNCT
# no => ADV => ADV
# física => ADJ => ADJ
# . => PUNCT => PUNCT
# En => ADP => ADP
# 1930 => NOUN => NOUN
# Subrahmanyan => PROPN => PROPN
# Chandrasekhar => PROPN => PROPN
# demostró => VERB => VERB
# que => SCONJ => SCONJ
# un => DET => DET
# cuerpo => NOUN => NOUN
# con => ADP => ADP
# una => DET => DET
# masa => NOUN => NOUN
# crítica => ADJ => ADJ
# ( => PUNCT => PUNCT
# ahora => ADV => ADV
# conocida => ADJ => ADJ
# como => SCONJ => SCONJ
# límite => NOUN => NOUN
# de => ADP => ADP
# Chandrasekhar => PROPN => PROPN
# ) => PUNCT => PUNCT
# y => CCONJ => CCONJ
# que => SCONJ => SCONJ
# no => ADV => ADV
# emitiese => VERB => VERB
# radiación => NOUN => NOUN
# , => PUNCT => PUNCT
# colapsaría => VERB => VERB
# por => ADP => ADP
# su => DET => DET
# propia => DET => DET
# gravedad => NOUN => NOUN
# porque => SCONJ => SCONJ
# no => ADV => ADV
# habría => AUX => AUX
# nada => PRON => PRON
# conocido => ADJ => ADJ
# que => SCONJ => SCONJ
# pudiera => AUX => AUX
# frenarla => VERB => VERB
# ( => PUNCT => PUNCT
# para => ADP => ADP
# dicha => ADJ => ADJ
# masa => NOUN => NOUN
# la => DET => DET
# fuerza => NOUN => NOUN
# de => ADP => ADP
# atracción => NOUN => NOUN
# gravitatoria => ADJ => ADJ
# sería => AUX => AUX
# mayor => ADJ => ADJ
# que => SCONJ => SCONJ
# la => DET => DET
# proporcionada => ADJ => ADJ
# por => ADP => ADP
# el => DET => DET
# principio => NOUN => NOUN
# de => ADP => ADP
# exclusión => NOUN => NOUN
# de => ADP => ADP
# Pauli => PROPN => PROPN
# ) => PUNCT => PUNCT
# . => PUNCT => PUNCT
# Sin => ADP => ADP
# embargo => NOUN => NOUN
# , => PUNCT => PUNCT
# Eddington => PROPN => PROPN
# se => PRON => PRON
# opuso => VERB => VERB
# a => ADP => ADP
# la => DET => DET
# idea => NOUN => NOUN
# de => ADP => ADP
# que => SCONJ => SCONJ
# la => DET => DET
# estrella => NOUN => NOUN
# alcanzara => VERB => VERB
# un => DET => DET
# tamaño => NOUN => NOUN
# nulo => ADJ => ADJ
# , => PUNCT => PUNCT
# lo => PRON => PRON
# que => PRON => PRON
# implicaría => VERB => VERB
# una => DET => DET
# singularidad => NOUN => NOUN
# desnuda => ADJ => ADJ
# de => ADP => ADP
# materia => NOUN => NOUN
# , => PUNCT => PUNCT
# y => CCONJ => CCONJ
# que => PRON => PRON
# debería => AUX => AUX
# haber => AUX => AUX
# algo => PRON => PRON
# que => PRON => PRON
# inevitablemente => ADV => ADV
# pusiera => VERB => VERB
# freno => NOUN => NOUN
# al => ADP => ADP
# colapso => NOUN => NOUN
# , => PUNCT => PUNCT
# línea => NOUN => NOUN
# adoptada => ADJ => ADJ
# por => ADP => ADP
# la => DET => DET
# mayoría => NOUN => NOUN
# de => ADP => ADP
# los => DET => DET
# científicos => NOUN => NOUN
# . => PUNCT => PUNCT
#
#
#  => SPACE => SPACE
# En => ADP => ADP
# 1939 => NOUN => NOUN
# Robert => PROPN => PROPN
# Oppenheimer => PROPN => PROPN
# predijo => VERB => VERB
# que => SCONJ => SCONJ
# una => DET => DET
# estrella => NOUN => NOUN
# masiva => ADJ => ADJ
# podría => AUX => AUX
# sufrir => VERB => VERB
# un => DET => DET
# colapso => NOUN => NOUN
# gravitatorio => ADJ => ADJ
# y => CCONJ => CCONJ
# , => PUNCT => PUNCT
# por => ADP => ADP
# tanto => NOUN => NOUN
# , => PUNCT => PUNCT
# los => DET => DET
# agujeros => NOUN => NOUN
# negros => ADJ => ADJ
# podrían => AUX => AUX
# ser => AUX => AUX
# formados => VERB => VERB
# en => ADP => ADP
# la => DET => DET
# naturaleza => NOUN => NOUN
# . => PUNCT => PUNCT
# Esta => DET => DET
# teoría => NOUN => NOUN
# no => ADV => ADV
# fue => AUX => AUX
# objeto => NOUN => NOUN
# de => ADP => ADP
# mucha => DET => DET
# atención => NOUN => NOUN
# hasta => ADP => ADP
# los => DET => DET
# años => NOUN => NOUN
# 1960 => NOUN => NOUN
# , => PUNCT => PUNCT
# porque => SCONJ => SCONJ
# , => PUNCT => PUNCT
# después => ADV => ADV
# de => ADP => ADP
# la => DET => DET
# Segunda => PROPN => PROPN
# Guerra => PROPN => PROPN
# Mundial => PROPN => PROPN
# se => PRON => PRON
# tenía => VERB => VERB
# más => ADV => ADV
# interés => NOUN => NOUN
# en => ADP => ADP
# lo => PRON => PRON
# que => PRON => PRON
# sucedía => VERB => VERB
# a => ADP => ADP
# escala => NOUN => NOUN
# atómica => ADJ => ADJ
# . => PUNCT => PUNCT
#
#
#  => SPACE => SPACE
# En => ADP => ADP
# 1967 => NOUN => NOUN
# Stephen => PROPN => PROPN
# Hawking => PROPN => PROPN
# y => CCONJ => CCONJ
# Roger => PROPN => PROPN
# Penrose => PROPN => PROPN
# probaron => VERB => VERB
# que => SCONJ => SCONJ
# los => DET => DET
# agujeros => NOUN => NOUN
# negros => ADJ => ADJ
# son => AUX => AUX
# soluciones => NOUN => NOUN
# a => ADP => ADP
# las => DET => DET
# ecuaciones => NOUN => NOUN
# de => ADP => ADP
# Einstein => PROPN => PROPN
# y => CCONJ => CCONJ
# que => SCONJ => SCONJ
# en => ADP => ADP
# determinados => ADJ => ADJ
# casos => NOUN => NOUN
# no => ADV => ADV
# se => PRON => PRON
# podría => AUX => AUX
# impedir => VERB => VERB
# que => SCONJ => SCONJ
# se => PRON => PRON
# crease => VERB => VERB
# un => DET => DET
# agujero => NOUN => NOUN
# negro => ADJ => ADJ
# a => ADP => ADP
# partir => NOUN => NOUN
# de => ADP => ADP
# un => DET => DET
# colapso => NOUN => NOUN
# . => PUNCT => PUNCT
# La => DET => DET
# idea => NOUN => NOUN
# de => ADP => ADP
# agujero => NOUN => NOUN
# negro => ADJ => ADJ
# tomó => VERB => VERB
# fuerza => NOUN => NOUN
# con => ADP => ADP
# los => DET => DET
# avances => NOUN => NOUN
# científicos => ADJ => ADJ
# y => CCONJ => CCONJ
# experimentales => ADJ => ADJ
# que => PRON => PRON
# llevaron => VERB => VERB
# al => ADP => ADP
# descubrimiento => NOUN => NOUN
# de => ADP => ADP
# los => DET => DET
# púlsares => NOUN => NOUN
# . => PUNCT => PUNCT
# Poco => ADV => ADV
# después => ADV => ADV
# , => PUNCT => PUNCT
# en => ADP => ADP
# 1969 => NOUN => NOUN
# , => PUNCT => PUNCT
# John => PROPN => PROPN
# Wheeler[11]​ => PROPN => PROPN
# acuñó => VERB => VERB
# la => DET => DET
# locución => NOUN => NOUN
# « => ADJ => ADJ
# agujero => NOUN => NOUN
# negro => ADJ => ADJ
# » => PROPN => PROPN
# durante => ADP => ADP
# una => DET => DET
# reunión => NOUN => NOUN
# de => ADP => ADP
# cosmólogos => NOUN => NOUN
# en => ADP => ADP
# Nueva => PROPN => PROPN
# York => PROPN => PROPN
# , => PUNCT => PUNCT
# para => ADP => ADP
# designar => VERB => VERB
# lo => PRON => PRON
# que => PRON => PRON
# anteriormente => ADV => ADV
# se => PRON => PRON
# llamó => VERB => VERB
# « => PROPN => PROPN
# estrella => NOUN => NOUN
# en => ADP => ADP
# colapso => NOUN => NOUN
# gravitatorio => ADJ => ADJ
# completo => ADJ => ADJ
# » => PUNCT => PUNCT
# . => PUNCT => PUNCT
#
#
#  => SPACE => SPACE
# El => DET => DET
# 10 => NUM => NUM
# de => ADP => ADP
# abril => NOUN => NOUN
# de => ADP => ADP
# 2019 => NUM => NUM
# el => DET => DET
# consorcio => NOUN => NOUN
# internacional => ADJ => ADJ
# Telescopio => PROPN => PROPN
# del => ADP => ADP
# Horizonte => PROPN => PROPN
# de => ADP => ADP
# Sucesos => PROPN => PROPN
# presentó => VERB => VERB
# la => DET => DET
# primera => ADJ => ADJ
# imagen => NOUN => NOUN
# jamás => ADV => ADV
# capturada => ADJ => ADJ
# de => ADP => ADP
# un => DET => DET
# agujero => NOUN => NOUN
# negro => ADJ => ADJ
# supermasivo => ADJ => ADJ
# ubicado => ADJ => ADJ
# en => ADP => ADP
# el => DET => DET
# centro => NOUN => NOUN
# de => ADP => ADP
# la => DET => DET
# galaxia => NOUN => NOUN
# M87 => PROPN => PROPN
# . => PUNCT => PUNCT
# Se => PRON => PRON
# esperaba => VERB => VERB
# a => ADP => ADP
# su => DET => DET
# vez => NOUN => NOUN
# el => DET => DET
# anuncio => NOUN => NOUN
# de => ADP => ADP
# otra => DET => DET
# imagen => NOUN => NOUN
# real => ADJ => ADJ
# de => ADP => ADP
# un => DET => DET
# agujero => NOUN => NOUN
# negro => ADJ => ADJ
# en => ADP => ADP
# Sagitario => PROPN => PROPN
# A => ADP => ADP
# * => PROPN => PROPN
# ; => PUNCT => PUNCT
# sin => ADP => ADP
# embargo => NOUN => NOUN
# , => PUNCT => PUNCT
# aclararon => VERB => VERB
# que => SCONJ => SCONJ
# no => ADV => ADV
# se => PRON => PRON
# había => AUX => AUX
# obtenido => VERB => VERB
# porque => SCONJ => SCONJ
# la => DET => DET
# fuente => NOUN => NOUN
# era => AUX => AUX
# muy => ADV => ADV
# variable => ADJ => ADJ
# durante => ADP => ADP
# los => DET => DET
# periodos => NOUN => NOUN
# de => ADP => ADP
# observación => NOUN => NOUN
# , => PUNCT => PUNCT
# resolviéndose => VERB => VERB
# en => ADP => ADP
# un => DET => DET
# futuro => NOUN => NOUN
